# %%
import pandas as pd
import numpy as np
import re
import string

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                I`d have responded, if I were going
# 1      549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2      088c60f138                          my boss is bullying me...
# 3      9642c003ef                     what interview! leave me alone
# 4      358bd9e861   Sons of ****, why couldn`t they put them on t...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on Denver  husband l...
# 27477  4f4c4fc327   I`ve wondered about rake to.  The client has ...
# 27478  f67aae2310   Yay good for both of you. Enjoy the break - y...
# 27479  ed167662a5                         But it was worth it  ****.
# 27480  6f7127d9d7     All this flirting going on - The ATG smiles...
#
#                                            selected_text sentiment
# 0                    I`d have responded, if I were going   neutral
# 1                                               Sooo SAD  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                          Sons of ****,  negative
# ...                                                  ...       ...
# 27476                                             d lost  negative
# 27477                                      , don`t force  negative
# 27478                          Yay good for both of you.  positive
# 27479                         But it was worth it  ****.  positive
# 27480  All this flirting going on - The ATG smiles. Y...   neutral
#
# [27481 rows x 4 columns]

# %%
# Clean data( remove punctuations, url and spaces)

def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub("\*+", "<CURSE>", text)
    return text

# %%
train_df[train_df.text.isna()]                   #Check for NULL values
# Out:
#          textID text selected_text sentiment
# 314  fdb77c3752  NaN           NaN   neutral

# %%
train_df.dropna(axis = 0, inplace=True)          #Drop Null values

# %%
#Clean text and selected_text column

train_df['text'] = train_df['text'].apply(lambda x: clean_text(x))
train_df['selected_text'] = train_df['selected_text'].apply(lambda x: clean_text(x))

# %%
train_df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                  id have responded if i were going
# 1  549e992a42         sooo sad i will miss you here in san diego
# 2  088c60f138                             my boss is bullying me
# 3  9642c003ef                      what interview leave me alone
# 4  358bd9e861   sons of  why couldnt they put them on the rel...
#
#                        selected_text sentiment
# 0  id have responded if i were going   neutral
# 1                           sooo sad  negative
# 2                        bullying me  negative
# 3                     leave me alone  negative
# 4                           sons of   negative

# %%
#Check all the rows where selected_text is empty

train_df[train_df.selected_text=='']
# Out:
#            textID                                               text  \
# 796    233b90417d   i never knew i could miss my phone so much fo...
# 891    584ed4d88e  not going to the dance recital and now i feel ...
# 962    ae1b6151f2                               facebook is being a
# 1044   ecf25bb855                 i hope theyr all wrong we need him
# 1759   89e7895985    apple store is down for updates whats coming...
# ...           ...                                                ...
# 25919  93fa13fa5b              my sisters  pc just blued screened me
# 26005  0b3fe0ca78
# 26371  1d1e147bed      oh fack u gave me police thats some seriouse
# 27360  64315d7fad  so im at the point now that it has become appa...
# 27427  413195db27    is wondering what happened to the sun  may grey
#
#       selected_text sentiment
# 796                  negative
# 891                  negative
# 962                  negative
# 1044                 negative
# 1759                 negative
# ...             ...       ...
# 25919                negative
# 26005                 neutral
# 26371                negative
# 27360                negative
# 27427                negative
#
# [103 rows x 4 columns]

# %%
#Check all the rows where text column is empty

train_df[train_df.text=='']
# Out:
#           textID text                 selected_text sentiment
# 1319  bc84f21e3b       shoesshoesshoesyayyayyayloli  positive
# 6399  d02b3284fd                                      neutral

# %%
#Drop all the rows where text or selected_text column is empty

train_df.drop(labels = train_df[train_df.text==''].index, inplace=True)
train_df.drop(labels = train_df[train_df.selected_text==''].index, inplace=True)

# %%
#Function for getting misspelled words from selected_text. 

def wrong_words(x):
    text, sel_text = x[0], x[1]
    wrg_words = []
    for word in sel_text.split():
        if word not in text.split():
            wrg_words.append(word)
    if len(wrg_words)>0:
        return (" ".join(wrg_words))
    else:
        return ("NO ERRORS")

# %%
train_df['misspelled'] = train_df[['text', 'selected_text']].apply(wrong_words, axis=1)

# %%
train_df[train_df.misspelled != "NO ERRORS"]
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 32     1c31703aef   if it is any consolation i got my bmi tested ...
# 39     2863f435bd  a little happy for the wine jeje ok itsm my fr...
# 48     3d9d4b0b55  i donbt like to peel prawns i also dont like g...
# ...           ...                                                ...
# 27426  132e051fe8    my cousins moved there like  years ago and i...
# 27456  d32efe060f          i wanna leave work already not feelin it
# 27470  778184dff1   lol i know  and hahadid you fall asleep or ju...
# 27474  8f14bb2715  so i get up early and i feel good about the da...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
#
#                                           selected_text sentiment misspelled
# 18                                                 onna  negative       onna
# 27                                          no internet  negative         no
# 32     well so much for being unhappy for about  minute  negative     minute
# 39                                    a little happy fo  positive         fo
# 48                                         dont like go  negative         go
# ...                                                 ...       ...        ...
# 27426                                             m sad  negative          m
# 27456                               wanna leave work al  negative         al
# 27470                                           t bored  negative          t
# 27474                                    i feel good ab  positive         ab
# 27476                                            d lost  negative          d
#
# [1875 rows x 5 columns]

# %%
train_df.head(30)
# Out:
#         textID                                               text  \
# 0   cb774db0d1                  id have responded if i were going
# 1   549e992a42         sooo sad i will miss you here in san diego
# 2   088c60f138                             my boss is bullying me
# 3   9642c003ef                      what interview leave me alone
# 4   358bd9e861   sons of  why couldnt they put them on the rel...
# 5   28b57f3990    some shameless plugging for the best rangers...
# 6   6e0c6d75b1   feedings for the baby are fun when he is all ...
# 7   50e14c0bb8                                         soooo high
# 8   e050245fbd                                        both of you
# 9   fc2cbefa9d   journey wow u just became cooler  hehe is tha...
# 10  2339a9b08b   as much as i love to be hopeful i reckon the ...
# 11  16fab9f95b  i really really like the song love story by ta...
# 12  74a76f6e0a       my sharpie is running dangerously low on ink
# 13  04dd1d2e34  i want to go to music tonight but i lost my voice
# 14  bbe3cbf620                             test test from the lg
# 15  8a939bfb59                               uh oh i am sunburned
# 16  3440297f8b   sok trying to plot alternatives as we speak sigh
# 17  919fa93391  ive been sick for the past few days  and thus ...
# 18  af3fed7fc3         is back home now      gonna miss every one
# 19  40e7becabf                         hes just not that into you
# 20  04d17ef61e   oh marly im so sorry  i hope you find her soon
# 21  e48b0b8a23  playing ghost online is really interesting the...
# 22  7de057cf40  is cleaning the house for her family who is co...
# 23  9ce5570064  gotta restart my computer  i thought  was supp...
# 24  0c8cc71c46  see wat i mean bout  friidays its called lose ...
# 25  e00c6ef376  the free fillin app on my ipod is fun im addicted
# 26  852edc3769                                           im sorry
# 27  bdc32ea43c   on the way to malaysiano internet access to twit
# 28  6ce4a4954b  juss came backk from berkeleyy  omg its madd f...
# 29  d22e6d40a7  went to sleep and there is a power cut in noid...
#
#                                         selected_text sentiment misspelled
# 0                   id have responded if i were going   neutral  NO ERRORS
# 1                                            sooo sad  negative  NO ERRORS
# 2                                         bullying me  negative  NO ERRORS
# 3                                      leave me alone  negative  NO ERRORS
# 4                                            sons of   negative  NO ERRORS
# 5     some shameless plugging for the best rangers...   neutral  NO ERRORS
# 6                                                 fun  positive  NO ERRORS
# 7                                          soooo high   neutral  NO ERRORS
# 8                                         both of you   neutral  NO ERRORS
# 9                            wow u just became cooler  positive  NO ERRORS
# 10  as much as i love to be hopeful i reckon the c...   neutral  NO ERRORS
# 11                                               like  positive  NO ERRORS
# 12                                        dangerously  negative  NO ERRORS
# 13                                               lost  negative  NO ERRORS
# 14                             test test from the lg    neutral  NO ERRORS
# 15                               uh oh i am sunburned  negative  NO ERRORS
# 16                                               sigh  negative  NO ERRORS
# 17                                               sick  negative  NO ERRORS
# 18                                               onna  negative       onna
# 19                         hes just not that into you   neutral  NO ERRORS
# 20   oh marly im so sorry  i hope you find her soon     neutral  NO ERRORS
# 21                                        interesting  positive  NO ERRORS
# 22  is cleaning the house for her family who is co...   neutral  NO ERRORS
# 23  gotta restart my computer  i thought  was supp...   neutral  NO ERRORS
# 24  see wat i mean bout  friidays its called lose ...   neutral  NO ERRORS
# 25  the free fillin app on my ipod is fun im addicted  positive  NO ERRORS
# 26                                           im sorry  negative  NO ERRORS
# 27                                        no internet  negative         no
# 28                                                fun  positive  NO ERRORS
# 29                      power back up not working too  negative  NO ERRORS

# %%
#Get all the rows where selected_text has error and contains single character as misspelled words. 

train_df[train_df['misspelled'].apply(lambda x: len(x)) == 1]
# Out:
#            textID                                               text  \
# 49     3fcea4debc   which case i got a new one last week and im n...
# 66     95e12b1cb1    hes awesome have you worked with him before ...
# 129    94f67cfa6d   hey mia  totally adore your music  when will ...
# 134    6903cb08f2   nice to see you tweeting  its sunday  may and...
# 166    c78bf59e67    lichfield tweetup sounds like fun  hope to s...
# ...           ...                                                ...
# 27153  a044ed928d   enjoy nola definitely one of my favorite citi...
# 27240  40143b692e                    who knows  it makes me sad  lol
# 27426  132e051fe8    my cousins moved there like  years ago and i...
# 27470  778184dff1   lol i know  and hahadid you fall asleep or ju...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
#
#                                   selected_text sentiment misspelled
# 49           d im not thrilled at all with mine  negative          d
# 66                                    s awesome  positive          s
# 129                                     y adore  positive          y
# 134                                      e nice  positive          e
# 166                           p sounds like fun  positive          p
# ...                                         ...       ...        ...
# 27153  y one of my favorite cities in the world  positive          y
# 27240                                     e sad  negative          e
# 27426                                     m sad  negative          m
# 27470                                   t bored  negative          t
# 27476                                    d lost  negative          d
#
# [682 rows x 5 columns]

# %%
# Remove all the single character words from selected_text

def clean_sel_text(x):
    text, sel_text, misspelled = x[0], x[1], x[2]
    sel_text = sel_text.split()
    sel_text.remove(misspelled)
    return " ".join(sel_text)

# %%
train_df['selected_text'] = train_df[['text', 'selected_text', 'misspelled']].apply(lambda x: clean_sel_text(x) if len(x['misspelled'])==1 else x['selected_text'], axis=1)

# %%
train_df[train_df.misspelled != "NO ERRORS"]
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 32     1c31703aef   if it is any consolation i got my bmi tested ...
# 39     2863f435bd  a little happy for the wine jeje ok itsm my fr...
# 48     3d9d4b0b55  i donbt like to peel prawns i also dont like g...
# ...           ...                                                ...
# 27426  132e051fe8    my cousins moved there like  years ago and i...
# 27456  d32efe060f          i wanna leave work already not feelin it
# 27470  778184dff1   lol i know  and hahadid you fall asleep or ju...
# 27474  8f14bb2715  so i get up early and i feel good about the da...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
#
#                                           selected_text sentiment misspelled
# 18                                                 onna  negative       onna
# 27                                          no internet  negative         no
# 32     well so much for being unhappy for about  minute  negative     minute
# 39                                    a little happy fo  positive         fo
# 48                                         dont like go  negative         go
# ...                                                 ...       ...        ...
# 27426                                               sad  negative          m
# 27456                               wanna leave work al  negative         al
# 27470                                             bored  negative          t
# 27474                                    i feel good ab  positive         ab
# 27476                                              lost  negative          d
#
# [1875 rows x 5 columns]

# %%
#Get all the rows having error, misspelled words with length>1 and sentiment is positive.

m = train_df[train_df['misspelled'].apply(lambda x: len(x)) > 1]

m[(m.misspelled!="NO ERRORS") & (m.sentiment=="positive")]
# Out:
#            textID                                               text  \
# 39     2863f435bd  a little happy for the wine jeje ok itsm my fr...
# 149    11c10e3fc5   shes unassuming and unpretentious shes just a...
# 168    e56eeb4968              few bevvies  in twngreat on a day off
# 240    7df7221145    thats why i need to be thereto represent the...
# 309    a54d3c2825                i know   it was worth a shot though
# ...           ...                                                ...
# 27339  27829d441f  just got out of the pool   so funnow gonna wat...
# 27376  13fbc75291  going to church in the morninghappy mommas day...
# 27386  e149ebd3a1   would one of the vwllers want to add this eve...
# 27401  261e064dd4   oh silence verona  i am wanting to go   jaja ...
# 27474  8f14bb2715  so i get up early and i feel good about the da...
#
#                       selected_text sentiment         misspelled
# 39                a little happy fo  positive                 fo
# 149                       endearing  positive          endearing
# 168                           great  positive              great
# 240    thats why i need to be there  positive              there
# 309                         as wort  positive            as wort
# ...                             ...       ...                ...
# 27339                        so fun  positive                fun
# 27376                         happy  positive              happy
# 27386                  ch appreciat  positive       ch appreciat
# 27401             ja enjoyyitverymu  positive  ja enjoyyitverymu
# 27474                i feel good ab  positive                 ab
#
# [539 rows x 5 columns]

# %%
#Get all the rows having error, misspelled words with length>1 and sentiment is negative.

m[(m.misspelled!="NO ERRORS") & (m.sentiment=="negative")]
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 32     1c31703aef   if it is any consolation i got my bmi tested ...
# 48     3d9d4b0b55  i donbt like to peel prawns i also dont like g...
# 60     52483f7da8  i lost all my friends im alone and sleepyi wan...
# ...           ...                                                ...
# 27209  30a1e8c2b4  guys      i know my ability to read time telli...
# 27280  e77145c41c   what happened  are you suffering from necksho...
# 27302  90c8aa60db  have i ever told you i absolutly hate writing ...
# 27362  7b82d63ee4  just found out i wont be tweeting from my phon...
# 27456  d32efe060f          i wanna leave work already not feelin it
#
#                                           selected_text sentiment misspelled
# 18                                                 onna  negative       onna
# 27                                          no internet  negative         no
# 32     well so much for being unhappy for about  minute  negative     minute
# 48                                         dont like go  negative         go
# 60            i lost all my friends im alone and sleepy  negative     sleepy
# ...                                                 ...       ...        ...
# 27209                                          es faile  negative   es faile
# 27280                                 i cant move eithe  negative      eithe
# 27302                                           hate wr  negative         wr
# 27362                                            c sorr  negative     c sorr
# 27456                               wanna leave work al  negative         al
#
# [506 rows x 5 columns]

# %%
#Get all the rows having error, misspelled words with length>1 and sentiment is neutral.

m[(m.misspelled!="NO ERRORS") & (m.sentiment=="neutral")]
# Out:
#            textID                                               text  \
# 251    77ba0fee75    powerblog what is this powerblog challenge y...
# 366    b751f39570   yea i should know but tell me everything  ps ...
# 581    1fce3e2d7b   no bueno  hollykins needs to feel better asap...
# 637    b04bbb81c9     hi to one kiwi artist from another kiwi artist
# 639    289317384e   oooo ok   why  havent you accepted my friends...
# ...           ...                                                ...
# 26870  ff77427519  will do it  in a  couple od days  when i have ...
# 26882  336b9cfc93     xdxdxd you crazy little thing why didnï¿½t ...
# 27067  c2dfc5875c  jamie  sean cody up for some angry  jamie  sea...
# 27111  44cf670176   haha itll be gross by the time it comes back ...
# 27349  f60f20ed09   yea but thats an old pic  she looks a lot dif...
#
#                                            selected_text sentiment  \
# 251    g what is this powerblog challenge you keep ta...   neutral
# 366    yea i should know but tell me everything  ps s...   neutral
# 581    no bueno  hollykins needs to feel better asap ...   neutral
# 637        hi to one kiwi artist from another kiwi artis   neutral
# 639    oooo ok   why  havent you accepted my friends ...   neutral
# ...                                                  ...       ...
# 26870  will do it  in a  couple od days  when i have ...   neutral
# 26882  dxd you crazy little thing why didnï¿½t you ge...   neutral
# 27067  amie  sean cody up for some angry  jamie  sean...   neutral
# 27111  haha itll be gross by the time it comes back  ...   neutral
# 27349  yea but thats an old pic  she looks a lot diff...   neutral
#
#         misspelled
# 251      g followe
# 366             ha
# 581    soproudofyo
# 637          artis
# 639          reque
# ...            ...
# 26870           pe
# 26882          dxd
# 27067         amie
# 27111        india
# 27349           lo
#
# [148 rows x 5 columns]

# %%
#Fuzzywuzzy library uses Levenshtein Distance for calculating difference between two sequences.

from fuzzywuzzy import fuzz
# Out:
# C:\Users\jainp\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Replace misspelled words with the words in text which has similarity of more than cutoff.

def check_fuzzy(x, cutoff):
    text, sel_text, misspelled = x[0], x[1], x[2]
    sel_text = sel_text.split()
    text =text.split()
    misspelled = misspelled.split()
    for m in misspelled:
        for t in text:
            if m in sel_text:
                if (fuzz.ratio(t,m)>cutoff):
                    index = sel_text.index(m)
                    
                    sel_text[index]= t
    return (" ".join(sel_text))

# %%
train_df[(train_df.misspelled!="NO ERRORS")]
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 32     1c31703aef   if it is any consolation i got my bmi tested ...
# 39     2863f435bd  a little happy for the wine jeje ok itsm my fr...
# 48     3d9d4b0b55  i donbt like to peel prawns i also dont like g...
# ...           ...                                                ...
# 27426  132e051fe8    my cousins moved there like  years ago and i...
# 27456  d32efe060f          i wanna leave work already not feelin it
# 27470  778184dff1   lol i know  and hahadid you fall asleep or ju...
# 27474  8f14bb2715  so i get up early and i feel good about the da...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
#
#                                           selected_text sentiment misspelled
# 18                                                 onna  negative       onna
# 27                                          no internet  negative         no
# 32     well so much for being unhappy for about  minute  negative     minute
# 39                                    a little happy fo  positive         fo
# 48                                         dont like go  negative         go
# ...                                                 ...       ...        ...
# 27426                                               sad  negative          m
# 27456                               wanna leave work al  negative         al
# 27470                                             bored  negative          t
# 27474                                    i feel good ab  positive         ab
# 27476                                              lost  negative          d
#
# [1875 rows x 5 columns]

# %%
#Replace misspelled words with the words in text which has similarity of more than 50.


train_df['selected_text']= train_df[['text', 'selected_text', 'misspelled']].apply(lambda x: check_fuzzy(x, 50) if (x['misspelled'])!= "NO ERRORS" else x["selected_text"], axis =1)

# %%
train_df[(train_df.misspelled!="NO ERRORS")]
# Out:
#            textID                                               text  \
# 18     af3fed7fc3         is back home now      gonna miss every one
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 32     1c31703aef   if it is any consolation i got my bmi tested ...
# 39     2863f435bd  a little happy for the wine jeje ok itsm my fr...
# 48     3d9d4b0b55  i donbt like to peel prawns i also dont like g...
# ...           ...                                                ...
# 27426  132e051fe8    my cousins moved there like  years ago and i...
# 27456  d32efe060f          i wanna leave work already not feelin it
# 27470  778184dff1   lol i know  and hahadid you fall asleep or ju...
# 27474  8f14bb2715  so i get up early and i feel good about the da...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
#
#                                           selected_text sentiment misspelled
# 18                                                gonna  negative       onna
# 27                                          no internet  negative         no
# 32     well so much for being unhappy for about minutes  negative     minute
# 39                                   a little happy for  positive         fo
# 48                                      dont like going  negative         go
# ...                                                 ...       ...        ...
# 27426                                               sad  negative          m
# 27456                               wanna leave work al  negative         al
# 27470                                             bored  negative          t
# 27474                                 i feel good about  positive         ab
# 27476                                              lost  negative          d
#
# [1875 rows x 5 columns]

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                  id have responded if i were going
# 1      549e992a42         sooo sad i will miss you here in san diego
# 2      088c60f138                             my boss is bullying me
# 3      9642c003ef                      what interview leave me alone
# 4      358bd9e861   sons of  why couldnt they put them on the rel...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
# 27477  4f4c4fc327   ive wondered about rake to  the client has ma...
# 27478  f67aae2310   yay good for both of you enjoy the break  you...
# 27479  ed167662a5                              but it was worth it
# 27480  6f7127d9d7     all this flirting going on  the atg smiles ...
#
#                                            selected_text sentiment misspelled
# 0                      id have responded if i were going   neutral  NO ERRORS
# 1                                               sooo sad  negative  NO ERRORS
# 2                                            bullying me  negative  NO ERRORS
# 3                                         leave me alone  negative  NO ERRORS
# 4                                               sons of   negative  NO ERRORS
# ...                                                  ...       ...        ...
# 27476                                               lost  negative          d
# 27477                                         dont force  negative  NO ERRORS
# 27478                           yay good for both of you  positive  NO ERRORS
# 27479                              but it was worth it    positive  NO ERRORS
# 27480  all this flirting going on  the atg smiles yay...   neutral  NO ERRORS
#
# [27376 rows x 5 columns]

# %%
#After all this processing, it is possible that many words in selected_text change to single character word or any other misspelled word is present,
#So, drop "misspelled" column and repeat the above cleaning steps again.
train_df =train_df.drop(columns=['misspelled'])

# %%
train_df
# Out:
#            textID                                               text  \
# 0      cb774db0d1                  id have responded if i were going
# 1      549e992a42         sooo sad i will miss you here in san diego
# 2      088c60f138                             my boss is bullying me
# 3      9642c003ef                      what interview leave me alone
# 4      358bd9e861   sons of  why couldnt they put them on the rel...
# ...           ...                                                ...
# 27476  4eac33d1c0   wish we could come see u on denver  husband l...
# 27477  4f4c4fc327   ive wondered about rake to  the client has ma...
# 27478  f67aae2310   yay good for both of you enjoy the break  you...
# 27479  ed167662a5                              but it was worth it
# 27480  6f7127d9d7     all this flirting going on  the atg smiles ...
#
#                                            selected_text sentiment
# 0                      id have responded if i were going   neutral
# 1                                               sooo sad  negative
# 2                                            bullying me  negative
# 3                                         leave me alone  negative
# 4                                               sons of   negative
# ...                                                  ...       ...
# 27476                                               lost  negative
# 27477                                         dont force  negative
# 27478                           yay good for both of you  positive
# 27479                              but it was worth it    positive
# 27480  all this flirting going on  the atg smiles yay...   neutral
#
# [27376 rows x 4 columns]

# %%
train_df['misspelled'] = train_df[['text', 'selected_text']].apply(wrong_words, axis=1)

# %%
m = train_df[train_df.misspelled!="NO ERRORS"]
m[m['misspelled'].apply(lambda x: len(x)) > 1]
# Out:
#            textID                                               text  \
# 27     bdc32ea43c   on the way to malaysiano internet access to twit
# 223    242d92151a  walking to class i hate not having a bikeespec...
# 362    b94aaf845e               please review sunehre ad placement
# 569    03f9f6f798  i dont think ive ever been so tierd in my life...
# 604    15f47296e2  soooim kinda o sick n tired of the bs that guy...
# ...           ...                                                ...
# 26687  c5de5361d2  does anyone out there want to be really awesom...
# 26883  ee30bf8953  im yours  jason mrazlooking for an electric gu...
# 27209  30a1e8c2b4  guys      i know my ability to read time telli...
# 27302  90c8aa60db  have i ever told you i absolutly hate writing ...
# 27456  d32efe060f          i wanna leave work already not feelin it
#
#                                            selected_text sentiment misspelled
# 27                                           no internet  negative         no
# 223                             i hate not having a bike  negative       bike
# 362                                            please re  positive         re
# 569      i dont think ive ever been so tierd in my lifeu  negative      lifeu
# 604                              im kinda o sick n tired  negative         im
# ...                                                  ...       ...        ...
# 26687  does anyone out there want to be really awesom...   neutral         ht
# 26883                                                yay  positive        yay
# 27209                                          es failed  negative         es
# 27302                                            hate wr  negative         wr
# 27456                                wanna leave work al  negative         al
#
# [146 rows x 5 columns]

# %%
train_df['selected_text'] = train_df[['text', 'selected_text', 'misspelled']].apply(lambda x: clean_sel_text(x) if len(x['misspelled'])==1 else x['selected_text'], axis=1)

# %%
train_df['selected_text']= train_df[['text', 'selected_text', 'misspelled']].apply(lambda x: check_fuzzy(x,30) if (x['misspelled'])!= "NO ERRORS" else x["selected_text"], axis =1)

# %%
train_df =train_df.drop(columns=['misspelled'])

# %%
train_df['misspelled'] = train_df[['text', 'selected_text']].apply(wrong_words, axis=1)

# %%
train_df[train_df.misspelled!="NO ERRORS"]
# Out:
#            textID                                               text  \
# 1588   a7f72a928a   woooooooooo   are you coming to nottingham at...
# 5697   e8c90dee68  im kinda bored anyone else i think ill listen ...
# 7410   3463ecdfd6  imintheroom imwatchingthehannahmoviewithmomshe...
# 16201  e78c1ad3f5                                off to work off at
# 25293  2fdbe40c03  grreverytime he gets a new girlfriendim at the...
#
#                                            selected_text sentiment  \
# 1588                                     to lovelovelove  positive
# 5697   im kinda bored anyone else i think ill listen ...   neutral
# 7410                                               great  positive
# 16201                                          lammmeeee  negative
# 25293                 im at the bottom of the totem pole  negative
#
#          misspelled
# 1588   lovelovelove
# 5697             ww
# 7410          great
# 16201     lammmeeee
# 25293            im

# %%
#Still, there are few records are remaining which has some error in selected_text.
#But we have only 4-5 rows like this, so we can correct that manually.

# %%
train_df.loc[1588].selected_text = 'woooooooooo'
train_df.loc[5697].selected_text = 'im kinda bored'
train_df.loc[7410].text = 'i m in the room im watching the hannah movie with mom, she said this film is very great .'
train_df.loc[16201].selected_text = 'off to work'
train_df.loc[25293].selected_text = 'at the bottom of the totem pole'

# %%
train_df =train_df.drop(columns=['misspelled'])

# %%
#Again check for any misspelled words.
train_df['misspelled'] = train_df[['text', 'selected_text']].apply(wrong_words, axis=1)

# %%
# No errors in selected_text now.
train_df[train_df.misspelled!="NO ERRORS"]
# Out:
# Empty DataFrame
# Columns: [textID, text, selected_text, sentiment, misspelled]
# Index: []

# %%
train_df =train_df.drop(columns=['misspelled'])

# %%
#Save cleaned file as csv
train_df.to_csv('cleaned_data.csv', index=False)
